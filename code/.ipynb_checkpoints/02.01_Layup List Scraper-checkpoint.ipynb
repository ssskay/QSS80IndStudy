# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import html5lib
import time
from bs4 import BeautifulSoup
from selenium import webdriver
from dotenv import load_dotenv

# uses env file to store LayupList login information
load_dotenv()

LAYUPLIST_EMAIL = os.getenv('LAYUPLIST_EMAIL')
LAYUPLIST_PASSWORD = os.getenv('LAYUPLIST_PASSWORD')

# reads in course and department catalog
course_db = pd.read_csv ('../data/course_db.csv')
course_code_db = pd.read_csv ('../data/course_code_db.csv')

# logs into layuplist
driver = webdriver.Chrome('/Users/sarakay/Downloads/chromedriver')  # Optional argument, if not specified will search path.
driver.get('https://www.layuplist.com/accounts/login/');
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:21: DeprecationWarning: executable_path has been deprecated, please pass in a Service object

# %%
driver.find_element_by_id("login-email").send_keys(LAYUPLIST_EMAIL)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   """Entry point for launching an IPython kernel.

# %%
driver.find_element_by_id("login-password").send_keys(LAYUPLIST_PASSWORD)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   """Entry point for launching an IPython kernel.

# %%
driver.find_element_by_xpath("/html/body/div/div[1]/div/div/div/div[5]/div/form/input[4]").click()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   """Entry point for launching an IPython kernel.

# %%
import re

driver.get('https://www.layuplist.com/departments')

# goes through each department name
for depart in course_code_db['Code']: 
    
    # does to page on layuplist containing department's courses
    URL = 'https://www.layuplist.com/search?q=' + depart
    driver.get(URL)
    
    # gets courses in department
    course_names = course_db[course_db['Course'].str.startswith(depart)]['Course']
    
    # goes to each course 
    for departCourse in course_names:
        driver.get(URL)
        print(departCourse)
        
        try:
            driver.find_element_by_partial_link_text(departCourse).click()
            soup = BeautifulSoup(driver.page_source)
            
            # gets number of pages of reviews to scrape
            maxNum = 1
            numRange = soup.findAll('ul')
            num = []
            urlStarter = driver.current_url
            for numbers in numRange:
                if 'of' in numbers.text:
                    num = re.findall('[0-9]+', numbers.text)
                    maxNum = int(num[1])
                    
            # list to store each page of reviews
            listToDF = []
            for i in range(1, maxNum + 1):
                newURL = urlStarter + '?page=' + str(i)
                driver.get(newURL)
                soup = BeautifulSoup(driver.page_source)

                paragraphs = soup.findAll('td')
                
                # puts review text into list
                for paragraph in paragraphs:
                    if paragraph.b != None:
                        listToDF.append(paragraph.text)
                        
            # creates dataframe from list of reviews
            coursedf = pd.DataFrame(listToDF, columns=['courseReviewRaw'])
            
            # labels which course review came from
            coursedf['Course'] = departCourse
            complete_df_list.append(coursedf)
        except:
            continue

# %%
complete_df_list
# Out:
# [                                     courseReviewRaw  \
#  0  \n08W\n with Lindsay F.:\n                    ...
#  1  \n08W\n with Lindsay F.:\n                    ...
#  2  \n08W\n with Lindsay F.:\n                    ...
#  3  \n07W\n with Ayo Coly:\n                      ...
#  4  \n07W\n with Ayo Coly:\n                      ...
#  5  \n05S\n with William W.:\n                    ...
#  6  \n05S\n with William W.:\n                    ...
#  7  \n01F\n with Ifi Amadiume:\n                  ...
#
#                          Course
#  0  AAAS007: First Year Seminar
#  1  AAAS007: First Year Seminar
#  2  AAAS007: First Year Seminar
#  3  AAAS007: First Year Seminar
#  4  AAAS007: First Year Seminar
#  5  AAAS007: First Year Seminar
#  6  AAAS007: First Year Seminar
#  7  AAAS007: First Year Seminar  ,
#                                       courseReviewRaw  \
#  0  \n20F\n with Adedoyin Ogunfeyimi And Clifford ...
#  1  \n20F\n with Adedoyin Ogunfeyimi And Clifford ...
#
#                                             Course
#  0  AAAS009: Introduction to AAAS Diaspora Studies
#  1  AAAS009: Introduction to AAAS Diaspora Studies  ,
#                                        courseReviewRaw  \
#  0   \n21S\n with Clifford Campbell:\n             ...
#  1   \n19F\n with Clifford Campbell:\n             ...
#  2   \n16F\n with Jesse Shipley:\n                 ...
#  3   \n09F\n with Soyica Colbert:\n                ...
#  4   \n09F\n with Soyica Colbert:\n                ...
#  5   \n08W\n with Michael Chaney:\n                ...
#  6   \n05F\n with J. Martin:\n                     ...
#  7   \n05F\n with J. Martin:\n                     ...
#  8   \n05F\n with J. Martin:\n                     ...
#  9   \n05F\n with J. Martin:\n                     ...
#  10  \n05F\n with J. Martin:\n                     ...
#  11  \n04S\n with Adam F.:\n                       ...
#  12  \n04S\n with Adam F.:\n                       ...
#  13  \n03S\n with J. Martin:\n                     ...
#
#                                                 Course
#  0   AAAS010: Introduction to African-American Studies
#  1   AAAS010: Introduction to African-American Studies
#  2   AAAS010: Introduction to African-American Studies
#  3   AAAS010: Introduction to African-American Studies
#  4   AAAS010: Introduction to African-American Studies
#  5   AAAS010: Introduction to African-American Studies
#  6   AAAS010: Introduction to African-American Studies
#  7   AAAS010: Introduction to African-American Studies
#  8   AAAS010: Introduction to African-American Studies
#  9   AAAS010: Introduction to African-American Studies
#  10  AAAS010: Introduction to African-American Studies
#  11  AAAS010: Introduction to African-American Studies
#  12  AAAS010: Introduction to African-American Studies
#  13  AAAS010: Introduction to African-American Studies  ,
#                                       courseReviewRaw  \
#  0  \n21F\n with Clifford Campbell:\n             ...
#  1  \n19S\n with Clifford Campbell:\n             ...
#  2  \n19F\n with Clifford Campbell:\n             ...
#  3  \n19F\n with Clifford Campbell:\n             ...
#  4  \n06S\n with Ifi Amadiume:\n                  ...
#  5  \n05S\n with Judith A.:\n                     ...
#  6  \n05S\n with Judith A.:\n                     ...
#  7  \n05S\n with Judith A.:\n                     ...
#  8  \n03S\n with Ifi Amadiume:\n                  ...
#
#                                       Course
#  0  AAAS011: Introduction to African Studies
#  1  AAAS011: Introduction to African Studies
#  2  AAAS011: Introduction to African Studies
#  3  AAAS011: Introduction to African Studies
#  4  AAAS011: Introduction to African Studies
#  5  AAAS011: Introduction to African Studies
#  6  AAAS011: Introduction to African Studies
#  7  AAAS011: Introduction to African Studies
#  8  AAAS011: Introduction to African Studies  ,
#                                       courseReviewRaw  \
#  0  \n21F\n with Darryl Barthe:\n                 ...
#  1  \n21F\n with Darryl Barthe:\n                 ...
#  2  \n09S\n with Celia E.:\n                      ...
#  3  \n08W\n with Celia E.:\n                      ...
#  4  \n08W\n with Celia E.:\n                      ...
#  5  \n08W\n with Celia E.:\n                      ...
#  6  \n05W\n with Celia E.:\n                      ...
#  7  \n03W\n with Craig S.:\n                      ...
#  8  \n03F\n with Celia E.:\n                      ...
#
#                                        Course
#  0  AAAS012: Race and Slavery in U.S. History
#  1  AAAS012: Race and Slavery in U.S. History
#  2  AAAS012: Race and Slavery in U.S. History
#  3  AAAS012: Race and Slavery in U.S. History
#  4  AAAS012: Race and Slavery in U.S. History
#  5  AAAS012: Race and Slavery in U.S. History
#  6  AAAS012: Race and Slavery in U.S. History
#  7  AAAS012: Race and Slavery in U.S. History
#  8  AAAS012: Race and Slavery in U.S. History  ,
#                                       courseReviewRaw  \
#  0  \n08F\n with Naaborko Sackeyfio:\n            ...
#  1  \n08F\n with Naaborko Sackeyfio:\n            ...
#  2  \n08F\n with Naaborko Sackeyfio:\n            ...
#  3  \n07F\n with Lindsay F.:\n                    ...
#  4  \n05F\n with Judith A.:\n                     ...
#  5  \n05F\n with Judith A.:\n                     ...
#  6  \n05F\n with Judith A.:\n                     ...
#  7  \n02F\n with Judith A.:\n                     ...
#
#                                    Course
#  0  AAAS014: Pre-Colonial African History
#  1  AAAS014: Pre-Colonial African History
#  2  AAAS014: Pre-Colonial African History
#  3  AAAS014: Pre-Colonial African History
#  4  AAAS014: Pre-Colonial African History
#  5  AAAS014: Pre-Colonial African History
#  6  AAAS014: Pre-Colonial African History
#  7  AAAS014: Pre-Colonial African History  ,
#                                       courseReviewRaw  \
#  0  \n09S\n with Naaborko Sackeyfio:\n            ...
#  1  \n08W\n with Lindsay F.:\n                    ...
#  2  \n06F\n with Judith A.:\n                     ...
#  3  \n06F\n with Judith A.:\n                     ...
#  4  \n06F\n with Judith A.:\n                     ...
#  5  \n05W\n with Judith A.:\n                     ...
#  6  \n05W\n with Judith A.:\n                     ...
#  7  \n05W\n with Judith A.:\n                     ...
#  8  \n05W\n with Judith A.:\n                     ...
#  9  \n02W\n with Judith A.:\n                     ...
#
#                                    Course
#  0  AAAS015: History of Africa since 1800
#  1  AAAS015: History of Africa since 1800
#  2  AAAS015: History of Africa since 1800
#  3  AAAS015: History of Africa since 1800
#  4  AAAS015: History of Africa since 1800
#  5  AAAS015: History of Africa since 1800
#  6  AAAS015: History of Africa since 1800
#  7  AAAS015: History of Africa since 1800
#  8  AAAS015: History of Africa since 1800
#  9  AAAS015: History of Africa since 1800  ,
#                                        courseReviewRaw  \
#  0   \n08W\n with Keith Walker:\n                  ...
#  1   \n08W\n with Keith Walker:\n                  ...
#  2   \n08W\n with Keith Walker:\n                  ...
#  3   \n07W\n with Beatriz Pastor:\n                ...
#  4   \n07W\n with Beatriz Pastor:\n                ...
#  5   \n07W\n with Beatriz Pastor:\n                ...
#  6   \n07W\n with Beatriz Pastor:\n                ...
#  7   \n07W\n with Beatriz Pastor:\n                ...
#  8   \n07W\n with Beatriz Pastor:\n                ...
#  9   \n07W\n with Beatriz Pastor:\n                ...
#  10  \n06S\n with Israel Reyes:\n                  ...
#  11  \n06S\n with Israel Reyes:\n                  ...
#  12  \n06S\n with Israel Reyes:\n                  ...
#  13  \n06S\n with Israel Reyes:\n                  ...
#  14  \n05W\n with Beatriz Pastor:\n                ...
#  15  \n05W\n with Beatriz Pastor:\n                ...
#  16  \n05W\n with Beatriz Pastor:\n                ...
#  17  \n05W\n with Beatriz Pastor:\n                ...
#
#                                                 Course
#  0   AAAS016: History, Culture and Society: The Man...
#  1   AAAS016: History, Culture and Society: The Man...
#  2   AAAS016: History, Culture and Society: The Man...
#  3   AAAS016: History, Culture and Society: The Man...
#  4   AAAS016: History, Culture and Society: The Man...
#  5   AAAS016: History, Culture and Society: The Man...
#  6   AAAS016: History, Culture and Society: The Man...
#  7   AAAS016: History, Culture and Society: The Man...
#  8   AAAS016: History, Culture and Society: The Man...
#  9   AAAS016: History, Culture and Society: The Man...
#  10  AAAS016: History, Culture and Society: The Man...
#  11  AAAS016: History, Culture and Society: The Man...
#  12  AAAS016: History, Culture and Society: The Man...
#  13  AAAS016: History, Culture and Society: The Man...
#  14  AAAS016: History, Culture and Society: The Man...
#  15  AAAS016: History, Culture and Society: The Man...
#  16  AAAS016: History, Culture and Society: The Man...
#  17  AAAS016: History, Culture and Society: The Man...  ,
#                                       courseReviewRaw  \
#  0  \n20W\n with Robert Baum:\n                   ...
#
#                                            Course
#  0  AAAS018.03: Introduction to African Religions  ,
#                                       courseReviewRaw  \
#  0  \n08W\n with Alexander I.:\n                  ...
#  1  \n08W\n with Alexander I.:\n                  ...
#  2  \n04X\n with Ifi Amadiume:\n                  ...
#  3  \n02F\n with Judith A.:\n                     ...
#
#                                         Course
#  0  AAAS018: Introduction to African Religions
#  1  AAAS018: Introduction to African Religions
#  2  AAAS018: Introduction to African Religions
#  3  AAAS018: Introduction to African Religions  ,
#                                       courseReviewRaw  \
#  0  \n19F\n with Clifford Campbell:\n             ...
#  1  \n09F\n with George Trumbull:\n               ...
#  2  \n08F\n with George Trumbull:\n               ...
#  3  \n08F\n with George Trumbull:\n               ...
#  4  \n08F\n with George Trumbull:\n               ...
#  5  \n08F\n with George Trumbull:\n               ...
#  6  \n06S\n with Cirri M.:\n                      ...
#
#                            Course
#  0  AAAS019: Africa and the World
#  1  AAAS019: Africa and the World
#  2  AAAS019: Africa and the World
#  3  AAAS019: Africa and the World
#  4  AAAS019: Africa and the World
#  5  AAAS019: Africa and the World
#  6  AAAS019: Africa and the World  ,
#                                       courseReviewRaw  \
#  0  \n17F\n with Vaughn Booker:\n                 ...
#
#                                                Course
#  0  AAAS022.10: African American Religion and Cult...  ,
#                                       courseReviewRaw  \
#  0  \n22W\n with Vaughn Booker:\n                 ...
#
#                                              Course
#  0  AAAS022: Religion and the Civil Rights Movement  ,
#                                       courseReviewRaw  \
#  0  \n05F\n with Judith A.:\n                     ...
#  1  \n05F\n with Judith A.:\n                     ...
#  2  \n05F\n with Judith A.:\n                     ...
#  3  \n05F\n with Judith A.:\n                     ...
#  4  \n02W\n with Judith A.:\n                     ...
#  5  \n02W\n with Judith A.:\n                     ...
#  6  \n02W\n with Judith A.:\n                     ...
#
#                                     Course
#  0  AAAS023: The Black Sporting Experience
#  1  AAAS023: The Black Sporting Experience
#  2  AAAS023: The Black Sporting Experience
#  3  AAAS023: The Black Sporting Experience
#  4  AAAS023: The Black Sporting Experience
#  5  AAAS023: The Black Sporting Experience
#  6  AAAS023: The Black Sporting Experience  ,
#                                       courseReviewRaw  \
#  0  \n18W\n with Deborah King:\n                  ...
#  1  \n11W\n with Deborah King:\n                  ...
#  2  \n11W\n with Deborah King:\n                  ...
#  3  \n08W\n with Deborah King:\n                  ...
#  4  \n08W\n with Deborah King:\n                  ...
#  5  \n08W\n with Deborah King:\n                  ...
#  6  \n05W\n with Deborah King:\n                  ...
#  7  \n04W\n with Deborah King:\n                  ...
#
#                                    Course
#  0  AAAS025: Constructing Black Womanhood
#  1  AAAS025: Constructing Black Womanhood
#  2  AAAS025: Constructing Black Womanhood
#  3  AAAS025: Constructing Black Womanhood
#  4  AAAS025: Constructing Black Womanhood
#  5  AAAS025: Constructing Black Womanhood
#  6  AAAS025: Constructing Black Womanhood
#  7  AAAS025: Constructing Black Womanhood  ,
#                                        courseReviewRaw                  Course
#  0   \n09S\n with Soyica Colbert:\n                ...  AAAS026: Toni Morrison
#  1   \n04W\n with Benjamin Forest:\n               ...  AAAS026: Toni Morrison
#  2   \n04F\n with Benjamin Forest:\n               ...  AAAS026: Toni Morrison
#  3   \n04F\n with Benjamin Forest:\n               ...  AAAS026: Toni Morrison
#  4   \n04F\n with Benjamin Forest:\n               ...  AAAS026: Toni Morrison
#  5   \n04F\n with Benjamin Forest:\n               ...  AAAS026: Toni Morrison
#  6   \n04F\n with Benjamin Forest:\n               ...  AAAS026: Toni Morrison
#  7   \n04F\n with Benjamin Forest:\n               ...  AAAS026: Toni Morrison
#  8   \n04F\n with Benjamin Forest:\n               ...  AAAS026: Toni Morrison
#  9   \n04F\n with Benjamin Forest:\n               ...  AAAS026: Toni Morrison
#  10  \n04F\n with Benjamin Forest:\n               ...  AAAS026: Toni Morrison
#  11  \n04F\n with Benjamin Forest:\n               ...  AAAS026: Toni Morrison
#  12  \n04F\n with Benjamin Forest:\n               ...  AAAS026: Toni Morrison
#  13  \n04F\n with Benjamin Forest:\n               ...  AAAS026: Toni Morrison
#  14  \n04F\n with Benjamin Forest:\n               ...  AAAS026: Toni Morrison
#  15  \n02X\n with Benjamin Forest:\n               ...  AAAS026: Toni Morrison
#  16  \n02X\n with Benjamin Forest:\n               ...  AAAS026: Toni Morrison
#  17  \n02X\n with Benjamin Forest:\n               ...  AAAS026: Toni Morrison
#  18  \n02X\n with Benjamin Forest:\n               ...  AAAS026: Toni Morrison,
#                                       courseReviewRaw  \
#  0  \n09F\n with Soyica Colbert:\n                ...
#  1  \n07F\n with Soyica Colbert:\n                ...
#  2  \n02S\n with Sydne Mahone:\n                  ...
#  3  \n02S\n with Sydne Mahone:\n                  ...
#  4  \n02S\n with Sydne Mahone:\n                  ...
#
#                             Course
#  0  AAAS031: Black Theater, U.S.A.
#  1  AAAS031: Black Theater, U.S.A.
#  2  AAAS031: Black Theater, U.S.A.
#  3  AAAS031: Black Theater, U.S.A.
#  4  AAAS031: Black Theater, U.S.A.  ,
#                                       courseReviewRaw  \
#  0  \n10X\n with J. Martin:\n                     ...
#  1  \n09F\n with J. Martin:\n                     ...
#
#                                         Course
#  0  AAAS033: The African American Intellectual
#  1  AAAS033: The African American Intellectual  ,
#                                       courseReviewRaw  \
#  0  \n08X\n with Michael Chaney:\n                ...
#  1  \n06S\n with William W.:\n                    ...
#  2  \n06F\n with Michael Chaney:\n                ...
#  3  \n06F\n with Michael Chaney:\n                ...
#  4  \n02S\n with William W.:\n                    ...
#  5  \n02S\n with William W.:\n                    ...
#
#                                       Course
#  0  AAAS034: Early Black American Literature
#  1  AAAS034: Early Black American Literature
#  2  AAAS034: Early Black American Literature
#  3  AAAS034: Early Black American Literature
#  4  AAAS034: Early Black American Literature
#  5  AAAS034: Early Black American Literature  ,
#                                        courseReviewRaw  \
#  0   \n20F\n with Joshua Bennett:\n                ...
#  1   \n18S\n with Chante Mouton Kinyon:\n          ...
#  2   \n07S\n with Shalene Vasquez:\n               ...
#  3   \n06W\n with J. Martin:\n                     ...
#  4   \n06W\n with J. Martin:\n                     ...
#  5   \n06W\n with J. Martin:\n                     ...
#  6   \n06W\n with J. Martin:\n                     ...
#  7   \n06W\n with J. Martin:\n                     ...
#  8   \n06W\n with J. Martin:\n                     ...
#  9   \n05S\n with J. Martin:\n                     ...
#  10  \n05S\n with J. Martin:\n                     ...
#  11  \n05S\n with J. Martin:\n                     ...
#  12  \n05S\n with J. Martin:\n                     ...
#  13  \n05S\n with J. Martin:\n                     ...
#  14  \n05S\n with J. Martin:\n                     ...
#  15  \n05S\n with J. Martin:\n                     ...
#  16  \n05S\n with J. Martin:\n                     ...
#  17  \n04S\n with Adam F.:\n                       ...
#
#                                         Course
#  0   AAAS035: Modern Black American Literature
#  1   AAAS035: Modern Black American Literature
#  2   AAAS035: Modern Black American Literature
#  3   AAAS035: Modern Black American Literature
#  4   AAAS035: Modern Black American Literature
#  5   AAAS035: Modern Black American Literature
#  6   AAAS035: Modern Black American Literature
#  7   AAAS035: Modern Black American Literature
#  8   AAAS035: Modern Black American Literature
#  9   AAAS035: Modern Black American Literature
#  10  AAAS035: Modern Black American Literature
#  11  AAAS035: Modern Black American Literature
#  12  AAAS035: Modern Black American Literature
#  13  AAAS035: Modern Black American Literature
#  14  AAAS035: Modern Black American Literature
#  15  AAAS035: Modern Black American Literature
#  16  AAAS035: Modern Black American Literature
#  17  AAAS035: Modern Black American Literature  ,
#                                       courseReviewRaw  \
#  0  \n20W\n with Clifford Campbell:\n             ...
#  1  \n20F\n with Clifford Campbell:\n             ...
#  2  \n20F\n with Clifford Campbell:\n             ...
#
#                              Course
#  0  AAAS036.50: Rasta and Rastafari
#  1  AAAS036.50: Rasta and Rastafari
#  2  AAAS036.50: Rasta and Rastafari  ,
#                                       courseReviewRaw  \
#  0  \n21S\n with William Blue V:\n                ...
#
#                                                Course
#  0  AAAS039.05: Utility of Death and Dying in Afri...  ,
#                                       courseReviewRaw  \
#  0  \n21F\n with Alison Martin:\n                 ...
#
#                                       Course
#  0  AAAS039.06: Hip-Hop in the United States  ,
#                                       courseReviewRaw  \
#  0  \n18S\n with Ayo Coly:\n                      ...
#  1  \n09W\n with Ayo Coly:\n                      ...
#  2  \n05F\n with Ayo Coly:\n                      ...
#  3  \n05F\n with Ayo Coly:\n                      ...
#
#                                                Course
#  0  AAAS040: Gender Identities and Politics in Africa
#  1  AAAS040: Gender Identities and Politics in Africa
#  2  AAAS040: Gender Identities and Politics in Africa
#  3  AAAS040: Gender Identities and Politics in Africa  ,
#                                       courseReviewRaw  \
#  0  \n01F\n with Ifi Amadiume:\n                  ...
#  1  \n01F\n with Ifi Amadiume:\n                  ...
#
#                                                Course
#  0  AAAS042: Women, Religion and Social Change in ...
#  1  AAAS042: Women, Religion and Social Change in ...  ,
#                                       courseReviewRaw  \
#  0  \n18F\n with Sabrina Billings:\n              ...
#
#                                                Course
#  0  AAAS044: Contemporary Africa: Exploring Myths,...  ,
#                                        courseReviewRaw  \
#  0   \n08W\n with Susanne Freidberg:\n             ...
#  1   \n08W\n with Susanne Freidberg:\n             ...
#  2   \n08W\n with Susanne Freidberg:\n             ...
#  3   \n08W\n with Susanne Freidberg:\n             ...
#  4   \n08W\n with Susanne Freidberg:\n             ...
#  5   \n08W\n with Susanne Freidberg:\n             ...
#  6   \n05S\n with Susanne Freidberg:\n             ...
#  7   \n05S\n with Susanne Freidberg:\n             ...
#  8   \n05S\n with Susanne Freidberg:\n             ...
#  9   \n04S\n with Susanne Freidberg:\n             ...
#  10  \n02S\n with Susanne Freidberg:\n             ...
#
#                                        Course
#  0   AAAS045: Africa: Ecology and Development
#  1   AAAS045: Africa: Ecology and Development
#  2   AAAS045: Africa: Ecology and Development
#  3   AAAS045: Africa: Ecology and Development
#  4   AAAS045: Africa: Ecology and Development
#  5   AAAS045: Africa: Ecology and Development
#  6   AAAS045: Africa: Ecology and Development
#  7   AAAS045: Africa: Ecology and Development
#  8   AAAS045: Africa: Ecology and Development
#  9   AAAS045: Africa: Ecology and Development
#  10  AAAS045: Africa: Ecology and Development  ,
#                                        courseReviewRaw  \
#  0   \n08S\n with Lindsay F.:\n                    ...
#  1   \n08S\n with Lindsay F.:\n                    ...
#  2   \n03F\n with Leo Spitzer:\n                   ...
#  3   \n03F\n with Leo Spitzer:\n                   ...
#  4   \n03F\n with Leo Spitzer:\n                   ...
#  5   \n03F\n with Leo Spitzer:\n                   ...
#  6   \n03F\n with Leo Spitzer:\n                   ...
#  7   \n03F\n with Leo Spitzer:\n                   ...
#  8   \n03F\n with Leo Spitzer:\n                   ...
#  9   \n03F\n with Leo Spitzer:\n                   ...
#  10  \n03F\n with Leo Spitzer:\n                   ...
#  11  \n03F\n with Leo Spitzer:\n                   ...
#
#                                       Course
#  0   AAAS046: History of Modern South Africa
#  1   AAAS046: History of Modern South Africa
#  2   AAAS046: History of Modern South Africa
#  3   AAAS046: History of Modern South Africa
#  4   AAAS046: History of Modern South Africa
#  5   AAAS046: History of Modern South Africa
#  6   AAAS046: History of Modern South Africa
#  7   AAAS046: History of Modern South Africa
#  8   AAAS046: History of Modern South Africa
#  9   AAAS046: History of Modern South Africa
#  10  AAAS046: History of Modern South Africa
#  11  AAAS046: History of Modern South Africa  ,
#                                       courseReviewRaw  \
#  0  \n09S\n with Douglas Haynes:\n                ...
#  1  \n08W\n with Douglas Haynes:\n                ...
#
#                                                Course
#  0  AAAS050: Colonialism, Development, and the Env...
#  1  AAAS050: Colonialism, Development, and the Env...  ,
#                                        courseReviewRaw  \
#  0   \n21W\n with Ayo Coly:\n                      ...
#  1   \n18F\n with Ayo Coly:\n                      ...
#  2   \n18F\n with Ayo Coly:\n                      ...
#  3   \n07F\n with Ayo Coly:\n                      ...
#  4   \n07F\n with Ayo Coly:\n                      ...
#  5   \n07F\n with Ayo Coly:\n                      ...
#  6   \n07F\n with Ayo Coly:\n                      ...
#  7   \n07F\n with Ayo Coly:\n                      ...
#  8   \n06W\n with Ayo Coly:\n                      ...
#  9   \n06W\n with Ayo Coly:\n                      ...
#  10  \n06F\n with Ayo Coly:\n                      ...
#  11  \n06F\n with Ayo Coly:\n                      ...
#  12  \n06F\n with Ayo Coly:\n                      ...
#  13  \n04F\n with Ayo Coly:\n                      ...
#
#                                                 Course
#  0   AAAS051: African Literatures: Masterpieces of ...
#  1   AAAS051: African Literatures: Masterpieces of ...
#  2   AAAS051: African Literatures: Masterpieces of ...
#  3   AAAS051: African Literatures: Masterpieces of ...
#  4   AAAS051: African Literatures: Masterpieces of ...
#  5   AAAS051: African Literatures: Masterpieces of ...
#  6   AAAS051: African Literatures: Masterpieces of ...
#  7   AAAS051: African Literatures: Masterpieces of ...
#  8   AAAS051: African Literatures: Masterpieces of ...
#  9   AAAS051: African Literatures: Masterpieces of ...
#  10  AAAS051: African Literatures: Masterpieces of ...
#  11  AAAS051: African Literatures: Masterpieces of ...
#  12  AAAS051: African Literatures: Masterpieces of ...
#  13  AAAS051: African Literatures: Masterpieces of ...  ,
#                                       courseReviewRaw  \
#  0  \n09S\n with George Trumbull:\n               ...
#  1  \n09S\n with George Trumbull:\n               ...
#
#                                                Course
#  0  AAAS052: The History of North Africa from the ...
#  1  AAAS052: The History of North Africa from the ...  ,
#                                       courseReviewRaw                   Course
#  0  \n05W\n with Ayo Coly:\n                      ...  AAAS055: African Cinema
#  1  \n05F\n with Ayo Coly:\n                      ...  AAAS055: African Cinema
#  2  \n05F\n with Ayo Coly:\n                      ...  AAAS055: African Cinema
#  3  \n05F\n with Ayo Coly:\n                      ...  AAAS055: African Cinema,
#                                       courseReviewRaw  \
#  0  \n05S\n with Ifi Amadiume:\n                  ...
#  1  \n05S\n with Ifi Amadiume:\n                  ...
#
#                                                Course
#  0  AAAS062: Nationalism and Revolution in the Car...
#  1  AAAS062: Nationalism and Revolution in the Car...  ,
#                                       courseReviewRaw  \
#  0  \n21X\n with Andrew Caplan:\n                 ...
#
#                                                Course
#  0  AAAS065.65: Silence, Exile, and Cunning: Compa...  ,
#                                       courseReviewRaw  \
#  0  \n07F\n with Ayo Coly:\n                      ...
#  1  \n07F\n with Ayo Coly:\n                      ...
#  2  \n07F\n with Ayo Coly:\n                      ...
#
#                                               Course
#  0  AAAS067: Colonial and Postcolonial Masculinities
#  1  AAAS067: Colonial and Postcolonial Masculinities
#  2  AAAS067: Colonial and Postcolonial Masculinities  ,
#                                       courseReviewRaw  \
#  0  \n20W\n with Trica Keaton:\n                  ...
#
#                        Course
#  0  AAAS068: Afro/Black Paris  ,
#                                       courseReviewRaw  \
#  0  \n17F\n with Francesca Inglese:\n             ...
#
#                                          Course
#  0  AAAS088.14: Cities, Subjects & Sonic Africa  ,
#                                       courseReviewRaw  \
#  0  \n18X\n with Jesse Shipley:\n                 ...
#
#                                        Course
#  0  AAAS088.16: Sovereignty, Race, and Rights  ,
#                                       courseReviewRaw  \
#  0  \n21X\n with Michael Chaney:\n                ...
#
#                                                Course
#  0  AAAS088.19: Contemporary African American Visu...  ]

# %%
layuplistreviews = pd.concat(complete_df_list)
layuplistreviews
# Out:
#                                       courseReviewRaw  \
# 0   \n08W\n with Lindsay F.:\n                    ...
# 1   \n08W\n with Lindsay F.:\n                    ...
# 2   \n08W\n with Lindsay F.:\n                    ...
# 3   \n07W\n with Ayo Coly:\n                      ...
# 4   \n07W\n with Ayo Coly:\n                      ...
# ..                                                ...
# 6   \n09S\n with Jennifer Brooke:\n               ...
# 7   \n09S\n with Jennifer Brooke:\n               ...
# 8   \n09S\n with Jennifer Brooke:\n               ...
# 9   \n09S\n with Jennifer Brooke:\n               ...
# 10  \n09S\n with Jennifer Brooke:\n               ...
#
#                                    Course
# 0             AAAS007: First Year Seminar
# 1             AAAS007: First Year Seminar
# 2             AAAS007: First Year Seminar
# 3             AAAS007: First Year Seminar
# 4             AAAS007: First Year Seminar
# ..                                    ...
# 6   WRIT043: The Written Judicial Opinion
# 7   WRIT043: The Written Judicial Opinion
# 8   WRIT043: The Written Judicial Opinion
# 9   WRIT043: The Written Judicial Opinion
# 10  WRIT043: The Written Judicial Opinion
#
# [29030 rows x 2 columns]

# %%
layuplistreviews.to_csv ('../data/layuplist_reviews.csv', index = False, header=True)
