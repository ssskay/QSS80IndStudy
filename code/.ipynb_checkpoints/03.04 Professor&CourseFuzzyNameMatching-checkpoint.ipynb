# %%
# scrapes faculty directory for prof names

import requests
from bs4 import BeautifulSoup
import pandas as pd


faculty_name = []

# manually got the max num of pages in directory
for i in range(1, 34):
    URL = 'https://faculty-directory.dartmouth.edu/department?dept=All&page=' + str(i)

    page = requests.get(URL)
    soup = BeautifulSoup(page.content, "html.parser")

    result = soup.find_all('span', 'class' == 'field-content')
    faculty_name += [r.text for r in result if r.text != '']

# %%
# df of all faculty at Dartmouth
faculty_name = set(faculty_name)
prof_df = pd.DataFrame(faculty_name, columns=['ProfessorName'])
prof_df
# Out:
#                 ProfessorName
# 0     Margaretha Kramer-Hajos
# 1       Sabrina Joan Billings
# 2              Prasad Jayanti
# 3            Hsien-Chih Chang
# 4             James E. Dobson
# ..                        ...
# 811  Sandra S. Mefoude Obiono
# 812          G. Eric Schaller
# 813            Thomas P. Jack
# 814       James Goodwin Rice
# 815     Francis J. Magilligan
#
# [816 rows x 1 columns]

# %%
# reads in course reviews for professor names
import pandas as pd
course_review_db = pd.read_csv('../data/course_review_db.csv', index_col = 0)
course_review_db
# Out:
#                             Course Department Term            Prof  \
# 0      AAAS007: First Year Seminar       AAAS  08W      Lindsay F.
# 1      AAAS007: First Year Seminar       AAAS  08W      Lindsay F.
# 2      AAAS007: First Year Seminar       AAAS  08W      Lindsay F.
# 3      AAAS007: First Year Seminar       AAAS  07W        Ayo Coly
# 4      AAAS007: First Year Seminar       AAAS  07W        Ayo Coly
# ...                            ...        ...  ...             ...
# 56922   WRIT 07.24: Past Imperfect       WRIT  19S  Cynthia Monroe
# 56923   WRIT 07.24: Past Imperfect       WRIT  19S  Cynthia Monroe
# 56924   WRIT 07.24: Past Imperfect       WRIT  19S  Cynthia Monroe
# 56925   WRIT 07.24: Past Imperfect       WRIT  19S  Cynthia Monroe
# 56926   WRIT 07.24: Past Imperfect       WRIT  19S  Cynthia Monroe
#
#                                                   Review
# 0      Never having studied African history, the mate...
# 1      I personally am not that interested by the top...
# 2      the professor was uninspiring and was easily i...
# 3      The pace of this course is a little hectic. It...
# 4      This class definitely had a lot of reading to ...
# ...                                                  ...
# 56922  I enjoyed the course and learned a lot about h...
# 56923  I think of and read history in a new way now. ...
# 56924       It made me like studying history a bit more.
# 56925  It made me more optimistic. I found the Profes...
# 56926                                          Not a lot
#
# [85955 rows x 5 columns]

# %%
# Sample professor who has multiple names
course_review_db[course_review_db['Prof'] == 'Sebastiaan Joosten']
# Out:
#                                                  Course Department Term  \
# 6267  COSC030: Discrete Mathematics in Computer Science       COSC  21W
# 6274  COSC030: Discrete Mathematics in Computer Science       COSC  20X
# 6275  COSC030: Discrete Mathematics in Computer Science       COSC  20X
# 6281  COSC030: Discrete Mathematics in Computer Science       COSC  20S
# 6562      COSC069.14: Functional Programming in Haskell      COSC.  20W
#
#                     Prof                                             Review
# 6267  Sebastiaan Joosten  (Reminder for future readers: this term was du...
# 6274  Sebastiaan Joosten  This class is normally bad, but Joosten made i...
# 6275  Sebastiaan Joosten  I would definitely not recommend taking this c...
# 6281  Sebastiaan Joosten  Quality of teaching improved dramatically as t...
# 6562  Sebastiaan Joosten  Joosten is not the best at explaining concepts...

# %%
course_review_db[course_review_db['Prof'] == 'Sebastiaan Joze Joosten']
# Out:
#                                        Course Department Term  \
# 6535               COSC060: Computer Networks       COSC  21F
# 6536               COSC060: Computer Networks       COSC  21F
# 6537               COSC060: Computer Networks       COSC  21F
# 20717    COSC 030: Discrete Math Computer Sci       COSC  20X
# 20718    COSC 030: Discrete Math Computer Sci       COSC  20X
# ...                                       ...        ...  ...
# 22385  COSC 98.02: Sr. Design&Impl Project II       COSC  21S
# 22386  COSC 98.02: Sr. Design&Impl Project II       COSC  21S
# 22387  COSC 98.02: Sr. Design&Impl Project II       COSC  21S
# 22388  COSC 98.02: Sr. Design&Impl Project II       COSC  21S
# 35708    ENGS 066: Discrete Math Computer Sci       ENGS  21W
#
#                           Prof  \
# 6535   Sebastiaan Joze Joosten
# 6536   Sebastiaan Joze Joosten
# 6537   Sebastiaan Joze Joosten
# 20717  Sebastiaan Joze Joosten
# 20718  Sebastiaan Joze Joosten
# ...                        ...
# 22385  Sebastiaan Joze Joosten
# 22386  Sebastiaan Joze Joosten
# 22387  Sebastiaan Joze Joosten
# 22388  Sebastiaan Joze Joosten
# 35708  Sebastiaan Joze Joosten
#
#                                                   Review
# 6535   Honestly pretty good class. Really cool and re...
# 6536   Very lecture heavy. Some lectures were made by...
# 6537   This class was all over the map. Joosten isn't...
# 20717  2 Midterms + Final Exam Drills due M, W, F Wee...
# 20718   A little too much work with daily drills and all
# ...                                                  ...
# 22385                         Learned a lot about Flask.
# 22386  Loved this class! we made a project that we ar...
# 22387  This really was a culminating experience! I go...
# 22388         it was the culminating course for my major
# 35708  I quite enjoyed this course and am considering...
#
# [211 rows x 5 columns]

# %%
from fuzzywuzzy import fuzz
import pandas as pd
import numpy as np

# sets up linking column between directory and review dataframe
dataframecolumn = pd.DataFrame(prof_df['ProfessorName'])
dataframecolumn.columns = ['directory_name']
compare = pd.DataFrame(set(course_review_db['Prof']))
compare.columns = ['fuzzy_match_name']

# merges names into combined dataframe
dataframecolumn['Key'] = 1
compare['Key'] = 1
combined_dataframe = dataframecolumn.merge(compare,on="Key",how="left")
combined_dataframe = combined_dataframe[~(combined_dataframe.directory_name==combined_dataframe.fuzzy_match_name)]

def partial_match(x,y):
    return(fuzz.ratio(x,y))
partial_match_vector = np.vectorize(partial_match)

# looks for names that are likely to match on directory name, ignore exact match
combined_dataframe['score']=partial_match_vector(combined_dataframe['directory_name'],combined_dataframe['fuzzy_match_name'])
combined_dataframe = combined_dataframe[combined_dataframe.score>=85]
combined_dataframe = combined_dataframe[combined_dataframe.score!=100]
combined_dataframe
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
#                    directory_name  Key       fuzzy_match_name  score
# 467       Margaretha Kramer-Hajos    1      Margaretha Kramer     85
# 2070        Sabrina Joan Billings    1       Sabrina Billings     86
# 6759             Hsien-Chih Chang    1       Hsien-chih Chang     94
# 8748              James E. Dobson    1           James Dobson     89
# 11017           Miles P. Blencowe    1         Miles Blencowe     90
# ...                           ...  ...                    ...    ...
# 1424015         Nurit Ben-Yehuda     1       Nurit Ben-yehuda     91
# 1431102         Hussein N. Kadhim    1         Hussein Kadhim     90
# 1433488  Sandra S. Mefoude Obiono    1  Sandra Mefoude Obiono     93
# 1438318            Thomas P. Jack    1            Thomas Jack     88
# 1440109     Francis J. Magilligan    1     Francis Magilligan     92
#
# [370 rows x 4 columns]

# %%
# sample name that fuzzy matches to two different names with same directory name
combined_dataframe[combined_dataframe['directory_name'] == 'Sebastiaan J. C. Joosten'].sort_values('score')
# Out:
#                   directory_name  Key         fuzzy_match_name  score
# 645253  Sebastiaan J. C. Joosten    1  Sebastiaan Joze Joosten     85
# 646285  Sebastiaan J. C. Joosten    1       Sebastiaan Joosten     86

# %%
# adjusts professor name based on fuzzy matching results
def fuzzmatcher(row):
    if combined_dataframe['fuzzy_match_name'].str.startswith(row['Prof']).any():
        return list(combined_dataframe[combined_dataframe['fuzzy_match_name'].str.startswith(row['Prof'])]['directory_name'])[0]
    else:
        return row['Prof']
    
course_review_db['Prof'] = course_review_db.apply(fuzzmatcher, axis = 1)
course_review_db
# Out:
#                             Course Department Term               Prof  \
# 0      AAAS007: First Year Seminar       AAAS  08W         Lindsay F.
# 1      AAAS007: First Year Seminar       AAAS  08W         Lindsay F.
# 2      AAAS007: First Year Seminar       AAAS  08W         Lindsay F.
# 3      AAAS007: First Year Seminar       AAAS  07W           Ayo Coly
# 4      AAAS007: First Year Seminar       AAAS  07W           Ayo Coly
# ...                            ...        ...  ...                ...
# 56922   WRIT 07.24: Past Imperfect       WRIT  19S  Cynthia P. Monroe
# 56923   WRIT 07.24: Past Imperfect       WRIT  19S  Cynthia P. Monroe
# 56924   WRIT 07.24: Past Imperfect       WRIT  19S  Cynthia P. Monroe
# 56925   WRIT 07.24: Past Imperfect       WRIT  19S  Cynthia P. Monroe
# 56926   WRIT 07.24: Past Imperfect       WRIT  19S  Cynthia P. Monroe
#
#                                                   Review
# 0      Never having studied African history, the mate...
# 1      I personally am not that interested by the top...
# 2      the professor was uninspiring and was easily i...
# 3      The pace of this course is a little hectic. It...
# 4      This class definitely had a lot of reading to ...
# ...                                                  ...
# 56922  I enjoyed the course and learned a lot about h...
# 56923  I think of and read history in a new way now. ...
# 56924       It made me like studying history a bit more.
# 56925  It made me more optimistic. I found the Profes...
# 56926                                          Not a lot
#
# [85955 rows x 5 columns]

# %%
# newly merged professor name
course_review_db[course_review_db['Prof'] == 'Sebastiaan J. C. Joosten']
# Out:
#                                                   Course Department Term  \
# 6267   COSC030: Discrete Mathematics in Computer Science       COSC  21W
# 6274   COSC030: Discrete Mathematics in Computer Science       COSC  20X
# 6275   COSC030: Discrete Mathematics in Computer Science       COSC  20X
# 6281   COSC030: Discrete Mathematics in Computer Science       COSC  20S
# 6535                          COSC060: Computer Networks       COSC  21F
# ...                                                  ...        ...  ...
# 22385             COSC 98.02: Sr. Design&Impl Project II       COSC  21S
# 22386             COSC 98.02: Sr. Design&Impl Project II       COSC  21S
# 22387             COSC 98.02: Sr. Design&Impl Project II       COSC  21S
# 22388             COSC 98.02: Sr. Design&Impl Project II       COSC  21S
# 35708               ENGS 066: Discrete Math Computer Sci       ENGS  21W
#
#                            Prof  \
# 6267   Sebastiaan J. C. Joosten
# 6274   Sebastiaan J. C. Joosten
# 6275   Sebastiaan J. C. Joosten
# 6281   Sebastiaan J. C. Joosten
# 6535   Sebastiaan J. C. Joosten
# ...                         ...
# 22385  Sebastiaan J. C. Joosten
# 22386  Sebastiaan J. C. Joosten
# 22387  Sebastiaan J. C. Joosten
# 22388  Sebastiaan J. C. Joosten
# 35708  Sebastiaan J. C. Joosten
#
#                                                   Review
# 6267   (Reminder for future readers: this term was du...
# 6274   This class is normally bad, but Joosten made i...
# 6275   I would definitely not recommend taking this c...
# 6281   Quality of teaching improved dramatically as t...
# 6535   Honestly pretty good class. Really cool and re...
# ...                                                  ...
# 22385                         Learned a lot about Flask.
# 22386  Loved this class! we made a project that we ar...
# 22387  This really was a culminating experience! I go...
# 22388         it was the culminating course for my major
# 35708  I quite enjoyed this course and am considering...
#
# [216 rows x 5 columns]

# %%
prof_df.to_csv('../data/professor_directory.csv')

# %%
# Example of mismatch course number/name
course_review_db[course_review_db['Course'].str.contains('Oceania')]
# Out:
#                               Course Department Term               Prof  \
# 1213  ANTH050.34: Peoples of Oceania      ANTH.  21W  Meredith Ferguson
# 1214  ANTH050.34: Peoples of Oceania      ANTH.  21F  Meredith Ferguson
# 1215  ANTH050.34: Peoples of Oceania      ANTH.  21F  Meredith Ferguson
# 1216  ANTH050.34: Peoples of Oceania      ANTH.  21F  Meredith Ferguson
# 1217  ANTH050.34: Peoples of Oceania      ANTH.  20W  Meredith Ferguson
# ...                              ...        ...  ...                ...
# 2557  ANTH 50.34: Peoples of Oceania       ANTH  21W  Meredith Ferguson
# 2558  ANTH 50.34: Peoples of Oceania       ANTH  21W  Meredith Ferguson
# 2559  ANTH 50.34: Peoples of Oceania       ANTH  21W  Meredith Ferguson
# 2560  ANTH 50.34: Peoples of Oceania       ANTH  21W  Meredith Ferguson
# 2561  ANTH 50.34: Peoples of Oceania       ANTH  21W  Meredith Ferguson
#
#                                                  Review
# 1213  Take this class!!! Professor Ferguson is the m...
# 1214  The easiest class I have took at Dartmouth. Ba...
# 1215  By far the easiest class I have ever taken. I ...
# 1216  The least work I've ever had for a Dartmouth c...
# 1217  10/10 would recommend this class. Professor Fe...
# ...                                                 ...
# 2557         Made me want to take more classes with her
# 2558  Reaffirmed my desire to be an anthro major and...
# 2559  This was the first anthropology class I've tak...
# 2560           Was able to branch out into new subjects
# 2561                                         it did not
#
# [171 rows x 5 columns]

# %%
course_db = pd.read_csv('../data/course_db.csv')
course_db
# Out:
#                                                  Course Distribs  Quality  \
# 0                           AAAS007: First Year Seminar      NaN      1.0
# 1        AAAS009: Introduction to AAAS Diaspora Studies  CI, INT      1.0
# 2     AAAS010: Introduction to African-American Studies  SOC, CI      6.0
# 3              AAAS011: Introduction to African Studies  SOC, NW      7.0
# 4             AAAS012: Race and Slavery in U.S. History   SOC, W      6.0
# ...                                                 ...      ...      ...
# 1800            WRIT007.33: Controv Sci and Pub Opinion      SOC      0.0
# 1801             WRIT007: First-year Seminar in Writing      NaN      4.0
# 1802                        WRIT008: Writing with Media      ART      1.0
# 1803                WRIT042: The Art of Science Writing      NaN      1.0
# 1804              WRIT043: The Written Judicial Opinion      SOC      7.0
#
#       Reviews
# 0         8.0
# 1         2.0
# 2        14.0
# 3         9.0
# 4         9.0
# ...       ...
# 1800      1.0
# 1801     10.0
# 1802      5.0
# 1803      1.0
# 1804     11.0
#
# [1805 rows x 4 columns]

# %%
from fuzzywuzzy import fuzz
import pandas as pd
import numpy as np

# sets up linking column between directory and review dataframe
dataframecolumn = pd.DataFrame(course_db['Course'])
dataframecolumn.columns = ['directory_name']
compare = pd.DataFrame(set(course_review_db['Course']))
compare.columns = ['fuzzy_match_name']

# merges names into combined dataframe
dataframecolumn['Key'] = 1
compare['Key'] = 1
combined_dataframe = dataframecolumn.merge(compare,on="Key",how="left")
combined_dataframe = combined_dataframe[~(combined_dataframe.directory_name==combined_dataframe.fuzzy_match_name)]

def partial_match(x,y):
    return(fuzz.ratio(x,y))
partial_match_vector = np.vectorize(partial_match)

# looks for names that are likely to match on directory name, ignore exact match
combined_dataframe['score']=partial_match_vector(combined_dataframe['directory_name'],combined_dataframe['fuzzy_match_name'])
combined_dataframe = combined_dataframe[combined_dataframe.score>=85]
combined_dataframe = combined_dataframe[combined_dataframe.score!=100]
combined_dataframe
# Out:
#                                             directory_name  Key  \
# 2195                           AAAS007: First Year Seminar    1
# 5812     AAAS010: Introduction to African-American Studies    1
# 9832              AAAS011: Introduction to African Studies    1
# 12378            AAAS012: Race and Slavery in U.S. History    1
# 16654                AAAS015: History of Africa since 1800    1
# ...                                                    ...  ...
# 4784251              WRIT003: Composition and Research: II    1
# 4788684                WRIT007.14: Learning from Dartmouth    1
# 4794514                   WRIT007.22: Technology and Sport    1
# 4803507                  WRIT007.27: Philosophy of Science    1
# 4821811              WRIT043: The Written Judicial Opinion    1
#
#                                           fuzzy_match_name  score
# 2195                            MUS007: First-Year Seminar     87
# 5812              AAAS011: Introduction to African Studies     88
# 9832     AAAS010: Introduction to African-American Studies     88
# 12378              HIST016: Race and Slavery in US History     88
# 16654                HIST066: History of Africa since 1800     86
# ...                                                    ...    ...
# 4784251               WRIT002: Composition and Research: I     96
# 4788684                WRIT 07.14: Learning from Dartmouth     97
# 4794514                   WRIT 07.22: Technology and Sport     97
# 4803507                     PHIL027: Philosophy of Science     86
# 4821811               WRIT 043: The Written Judicl Opinion     96
#
# [933 rows x 4 columns]

# %%
# adjusts professor name based on fuzzy matching results
def fuzzmatcher2(row):
    if combined_dataframe['fuzzy_match_name'].str.startswith(row['Course']).any():
        return list(combined_dataframe[combined_dataframe['fuzzy_match_name'].str.startswith(row['Course'])]['directory_name'])[0]
    else:
        return row['Course']
    
course_review_db['Course'] = course_review_db.apply(fuzzmatcher2, axis = 1)
course_review_db
# Out:
#                            Course Department Term               Prof  \
# 0      MUS007: First-Year Seminar       AAAS  08W         Lindsay F.
# 1      MUS007: First-Year Seminar       AAAS  08W         Lindsay F.
# 2      MUS007: First-Year Seminar       AAAS  08W         Lindsay F.
# 3      MUS007: First-Year Seminar       AAAS  07W           Ayo Coly
# 4      MUS007: First-Year Seminar       AAAS  07W           Ayo Coly
# ...                           ...        ...  ...                ...
# 56922  WRIT 07.24: Past Imperfect       WRIT  19S  Cynthia P. Monroe
# 56923  WRIT 07.24: Past Imperfect       WRIT  19S  Cynthia P. Monroe
# 56924  WRIT 07.24: Past Imperfect       WRIT  19S  Cynthia P. Monroe
# 56925  WRIT 07.24: Past Imperfect       WRIT  19S  Cynthia P. Monroe
# 56926  WRIT 07.24: Past Imperfect       WRIT  19S  Cynthia P. Monroe
#
#                                                   Review
# 0      Never having studied African history, the mate...
# 1      I personally am not that interested by the top...
# 2      the professor was uninspiring and was easily i...
# 3      The pace of this course is a little hectic. It...
# 4      This class definitely had a lot of reading to ...
# ...                                                  ...
# 56922  I enjoyed the course and learned a lot about h...
# 56923  I think of and read history in a new way now. ...
# 56924       It made me like studying history a bit more.
# 56925  It made me more optimistic. I found the Profes...
# 56926                                          Not a lot
#
# [85955 rows x 5 columns]

# %%
course_review_db.to_csv('../data/course_review_db_prof_course_name_cleaned.csv')
